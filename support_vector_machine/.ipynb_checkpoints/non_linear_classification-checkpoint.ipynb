# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles

# %%
import jupyterthemes as jt

# %%
jt -t monokai
# Out:
#   File "<ipython-input-10-70eb14957a8e>", line 1
#     jt -t monokai
#                 ^
# SyntaxError: invalid syntax

# %%
# Generate dataset
X, y = make_circles(n_samples=600, noise=0.05)

# SVM uses Labels {1, -1}
y[y==0] = -1

print(X.shape, y.shape)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()
# Out:
# (600, 2) (600,)
